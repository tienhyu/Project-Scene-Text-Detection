# %% [markdown]
# ## Download Dataset

# %%
# Download ICDAR 2003 dataset
# https://drive.google.com/file/d/1kUy2tuH-kKBlFCNA0a9sqD2TG4uyvBnV/view
# !gdown 1kUy2tuH-kKBlFCNA0a9sqD2TG4uyvBnV
# !unzip -q icdar2003.zip -d datasets

# %% [markdown]
# ## Prepare Dataset

# %%
import xml.etree.ElementTree as ET

words_xml_path = 'datasets/SceneTrialTrain/words.xml'
tree = ET.parse(words_xml_path)
root = tree.getroot()

print(root)
# Out:
# <Element 'tagset' at 0x74418c60bd30>

# %%
import xml.etree.ElementTree as ET

words_xml_path = 'datasets/SceneTrialTrain/words.xml'
tree = ET.parse(words_xml_path)
root = tree.getroot()

for image in root:
    print(image)
# Out:
# <Element 'image' at 0x74418c76e4d0>
# <Element 'image' at 0x74418c478900>
# <Element 'image' at 0x74418c478b80>
# <Element 'image' at 0x74418c479670>
# <Element 'image' at 0x74418c47a8e0>
# <Element 'image' at 0x74418c47b1f0>
# <Element 'image' at 0x74418c47bb00>
# <Element 'image' at 0x74418c498810>
# <Element 'image' at 0x74418c4997b0>
# <Element 'image' at 0x74418c499fd0>
# <Element 'image' at 0x74418c49af70>
# <Element 'image' at 0x74418c49b3d0>
# <Element 'image' at 0x74418c49bdd0>
# <Element 'image' at 0x74418c4b0360>
# <Element 'image' at 0x74418c4b08b0>
# <Element 'image' at 0x74418c4b0b30>
# <Element 'image' at 0x74418c4b19e0>
# <Element 'image' at 0x74418c4b1c60>
# <Element 'image' at 0x74418c4b2660>
# <Element 'image' at 0x74418c4b3060>
# <Element 'image' at 0x74418c4b3970>
# <Element 'image' at 0x74418c4b3ec0>
# <Element 'image' at 0x74418c4c8bd0>
# <Element 'image' at 0x74418c4cb4c0>
# <Element 'image' at 0x74418c4cbbf0>
# <Element 'image' at 0x74418c4cbf60>
# <Element 'image' at 0x74418c4e4400>
# <Element 'image' at 0x74418c4e4680>
# <Element 'image' at 0x74418c4e4ae0>
# <Element 'image' at 0x74418c4e5210>
# <Element 'image' at 0x74418c4e6480>
# <Element 'image' at 0x74418c4e67f0>
# <Element 'image' at 0x74418c4e73d0>
# <Element 'image' at 0x74418c3042c0>
# <Element 'image' at 0x74418c304ea0>
# <Element 'image' at 0x74418c305350>
# <Element 'image' at 0x74418c305c60>
# <Element 'image' at 0x74418c306390>
# <Element 'image' at 0x74418c306610>
# <Element 'image' at 0x74418c306980>
# <Element 'image' at 0x74418c306c00>
# <Element 'image' at 0x74418c307060>
# <Element 'image' at 0x74418c3075b0>
# <Element 'image' at 0x74418c307ec0>
# <Element 'image' at 0x74418c31c450>
# <Element 'image' at 0x74418c31cb80>
# <Element 'image' at 0x74418c31d0d0>
# <Element 'image' at 0x74418c31d620>
# <Element 'image' at 0x74418c31e110>
# <Element 'image' at 0x74418c31e7f0>
# <Element 'image' at 0x74418c31eca0>
# <Element 'image' at 0x74418c31f100>
# <Element 'image' at 0x74418c31f470>
# <Element 'image' at 0x74418c31f9c0>
# <Element 'image' at 0x74418c31fc40>
# <Element 'image' at 0x74418c31ffb0>
# <Element 'image' at 0x74418c334540>
# <Element 'image' at 0x74418c334a90>
# <Element 'image' at 0x74418c334d10>
# <Element 'image' at 0x74418c335080>
# <Element 'image' at 0x74418c335300>
# <Element 'image' at 0x74418c335580>
# <Element 'image' at 0x74418c335bc0>
# <Element 'image' at 0x74418c3363e0>
# <Element 'image' at 0x74418c337f60>
# <Element 'image' at 0x74418c34c900>
# <Element 'image' at 0x74418c34cb80>
# <Element 'image' at 0x74418c34d2b0>
# <Element 'image' at 0x74418c34d530>
# <Element 'image' at 0x74418c34de40>
# <Element 'image' at 0x74418c34e390>
# <Element 'image' at 0x74418c34e7f0>
# <Element 'image' at 0x74418c34ea70>
# <Element 'image' at 0x74418c34ecf0>
# <Element 'image' at 0x74418c34f150>
# <Element 'image' at 0x74418c34f880>
# <Element 'image' at 0x74418c34fce0>
# <Element 'image' at 0x74418c36c180>
# <Element 'image' at 0x74418c36c6d0>
# <Element 'image' at 0x74418c36c950>
# <Element 'image' at 0x74418c36cdb0>
# <Element 'image' at 0x74418c36dc60>
# <Element 'image' at 0x74418c36dee0>
# <Element 'image' at 0x74418c36e7f0>
# <Element 'image' at 0x74418c36ee30>
# <Element 'image' at 0x74418c36f0b0>
# <Element 'image' at 0x74418c36f8d0>
# <Element 'image' at 0x74418c36fd30>
# <Element 'image' at 0x74418c3844a0>
# <Element 'image' at 0x74418c3849f0>
# <Element 'image' at 0x74418c385030>
# <Element 'image' at 0x74418c385490>
# <Element 'image' at 0x74418c3859e0>
# <Element 'image' at 0x74418c386020>
# <Element 'image' at 0x74418c3862a0>
# <Element 'image' at 0x74418c386610>
# <Element 'image' at 0x74418c386980>
# <Element 'image' at 0x74418c387b00>
# <Element 'image' at 0x74418c39c180>
# <Element 'image' at 0x74418c39c5e0>
# <Element 'image' at 0x74418c39c950>
# <Element 'image' at 0x74418c39cdb0>
# <Element 'image' at 0x74418c39d3f0>
# <Element 'image' at 0x74418c39d670>
# <Element 'image' at 0x74418c39d9e0>
# <Element 'image' at 0x74418c39e110>
# <Element 'image' at 0x74418c39e390>
# <Element 'image' at 0x74418c39e610>
# <Element 'image' at 0x74418c39e890>
# <Element 'image' at 0x74418c39ec00>
# <Element 'image' at 0x74418c39ee80>
# <Element 'image' at 0x74418c39f100>
# <Element 'image' at 0x74418c39f470>
# <Element 'image' at 0x74418c39f9c0>
# <Element 'image' at 0x74418c39fe70>
# <Element 'image' at 0x74418c3b8220>
# <Element 'image' at 0x74418c3b8680>
# <Element 'image' at 0x74418c3b8bd0>
# <Element 'image' at 0x74418c3b9170>
# <Element 'image' at 0x74418c3b98a0>
# <Element 'image' at 0x74418c3b9b20>
# <Element 'image' at 0x74418c3b9e90>
# <Element 'image' at 0x74418c3ba110>
# <Element 'image' at 0x74418c3ba570>
# <Element 'image' at 0x74418c3ba7f0>
# <Element 'image' at 0x74418c3bae30>
# <Element 'image' at 0x74418c3bb470>
# <Element 'image' at 0x74418c3bb7e0>
# <Element 'image' at 0x74418c3d4130>
# <Element 'image' at 0x74418c3d44a0>
# <Element 'image' at 0x74418c3d5620>
# <Element 'image' at 0x74418c3d6c50>
# <Element 'image' at 0x74418c3d7560>
# <Element 'image' at 0x74418c3d77e0>
# <Element 'image' at 0x74418c3d7a60>
# <Element 'image' at 0x74418c3d7dd0>
# <Element 'image' at 0x74418c3f0540>
# <Element 'image' at 0x74418c3f1120>
# <Element 'image' at 0x74418c3f1580>
# <Element 'image' at 0x74418c3f19e0>
# <Element 'image' at 0x74418c3f1e40>
# <Element 'image' at 0x74418c3f20c0>
# <Element 'image' at 0x74418c3f2840>
# <Element 'image' at 0x74418c3f2ac0>
# <Element 'image' at 0x74418c3f32e0>
# <Element 'image' at 0x74418c3f3650>
# <Element 'image' at 0x74418c3f3ab0>
# <Element 'image' at 0x74418c3f3e20>
# <Element 'image' at 0x74418c2080e0>
# <Element 'image' at 0x74418c208630>
# <Element 'image' at 0x74418c208d60>
# <Element 'image' at 0x74418c208fe0>
# <Element 'image' at 0x74418c209260>
# <Element 'image' at 0x74418c2094e0>
# <Element 'image' at 0x74418c209850>
# <Element 'image' at 0x74418c209cb0>
# <Element 'image' at 0x74418c20a3e0>
# <Element 'image' at 0x74418c20a660>
# <Element 'image' at 0x74418c20ae80>
# <Element 'image' at 0x74418c20be20>
# <Element 'image' at 0x74418c2200e0>
# <Element 'image' at 0x74418c220540>
# <Element 'image' at 0x74418c220b80>
# <Element 'image' at 0x74418c220e00>
# <Element 'image' at 0x74418c2219e0>
# <Element 'image' at 0x74418c221c60>
# <Element 'image' at 0x74418c221ee0>
# <Element 'image' at 0x74418c2227f0>
# <Element 'image' at 0x74418c222a70>
# <Element 'image' at 0x74418c222cf0>
# <Element 'image' at 0x74418c222f70>
# <Element 'image' at 0x74418c2233d0>
# <Element 'image' at 0x74418c223740>
# <Element 'image' at 0x74418c2239c0>
# <Element 'image' at 0x74418c223c40>
# <Element 'image' at 0x74418c223ec0>
# <Element 'image' at 0x74418c238450>
# <Element 'image' at 0x74418c2386d0>
# <Element 'image' at 0x74418c238950>
# <Element 'image' at 0x74418c239080>
# <Element 'image' at 0x74418c239300>
# <Element 'image' at 0x74418c239580>
# <Element 'image' at 0x74418c239cb0>
# <Element 'image' at 0x74418c239f30>
# <Element 'image' at 0x74418c23a1b0>
# <Element 'image' at 0x74418c23a430>
# <Element 'image' at 0x74418c23aa70>
# <Element 'image' at 0x74418c23acf0>
# <Element 'image' at 0x74418c23b330>
# <Element 'image' at 0x74418c23b6a0>
# <Element 'image' at 0x74418c23b920>
# <Element 'image' at 0x74418c23bba0>
# <Element 'image' at 0x74418c23be20>
# <Element 'image' at 0x74418c2500e0>
# <Element 'image' at 0x74418c250360>
# <Element 'image' at 0x74418c2505e0>
# <Element 'image' at 0x74418c250b30>
# <Element 'image' at 0x74418c250db0>
# <Element 'image' at 0x74418c251120>
# <Element 'image' at 0x74418c251580>
# <Element 'image' at 0x74418c2518f0>
# <Element 'image' at 0x74418c251c60>
# <Element 'image' at 0x74418c251fd0>
# <Element 'image' at 0x74418c252520>
# <Element 'image' at 0x74418c252a70>
# <Element 'image' at 0x74418c253240>
# <Element 'image' at 0x74418c2534c0>
# <Element 'image' at 0x74418c253650>
# <Element 'image' at 0x74418c2537e0>
# <Element 'image' at 0x74418c26d490>
# <Element 'image' at 0x74418c26d620>
# <Element 'image' at 0x74418c26d7b0>
# <Element 'image' at 0x74418c26db20>
# <Element 'image' at 0x74418c26df80>
# <Element 'image' at 0x74418c26e7a0>
# <Element 'image' at 0x74418c26ea20>
# <Element 'image' at 0x74418c26ef70>
# <Element 'image' at 0x74418c26f3d0>
# <Element 'image' at 0x74418c26f920>
# <Element 'image' at 0x74418c26fd80>
# <Element 'image' at 0x74418c288220>
# <Element 'image' at 0x74418c288860>
# <Element 'image' at 0x74418c289080>
# <Element 'image' at 0x74418c2895d0>
# <Element 'image' at 0x74418c289b20>
# <Element 'image' at 0x74418c289e90>
# <Element 'image' at 0x74418c28a2f0>
# <Element 'image' at 0x74418c28a660>
# <Element 'image' at 0x74418c28aca0>
# <Element 'image' at 0x74418c28af70>
# <Element 'image' at 0x74418c28b4c0>
# <Element 'image' at 0x74418c28bab0>
# <Element 'image' at 0x74418c28bec0>
# <Element 'image' at 0x74418c2a4310>
# <Element 'image' at 0x74418c2a4630>
# <Element 'image' at 0x74418c2a4c20>
# <Element 'image' at 0x74418c2a53f0>
# <Element 'image' at 0x74418c2a59e0>
# <Element 'image' at 0x74418c2a5ee0>
# <Element 'image' at 0x74418c2a66b0>
# <Element 'image' at 0x74418c2a6bb0>
# <Element 'image' at 0x74418c2a6de0>
# <Element 'image' at 0x74418c2a75b0>
# <Element 'image' at 0x74418c2a7c90>
# <Element 'image' at 0x74418c2bc0e0>
# <Element 'image' at 0x74418c2bc6d0>
# <Element 'image' at 0x74418c2bcea0>
# <Element 'image' at 0x74418c2bd2b0>
# <Element 'image' at 0x74418c2bf4c0>
# <Element 'image' at 0x74418c2bfab0>

# %%
import xml.etree.ElementTree as ET

words_xml_path = 'datasets/SceneTrialTrain/words.xml'
tree = ET.parse(words_xml_path)
root = tree.getroot()

for image in root:
    print(image[0].text)
    print(image[1].attrib['x'], image[1].attrib['y'])
    break
# Out:
# apanar_06.08.2002/IMG_1261.JPG
# 1600 1200

# %%
import xml.etree.ElementTree as ET

words_xml_path = 'datasets/SceneTrialTrain/words.xml'
tree = ET.parse(words_xml_path)
root = tree.getroot()

for image in root:
    img_name = image[0].text  # Get the text of the first child element
    for bbs in image.findall('taggedRectangles'):
        for bb in bbs:
            bbox = [
                bb.attrib['x'],
                bb.attrib['y'],
                bb.attrib['width'],
                bb.attrib['height']
            ]
            print(bb[0].text, bbox)
    break
# Out:
# self ['174.0', '392.0', '274.0', '195.0']
# adhesive ['512.0', '391.0', '679.0', '183.0']
# address ['184.0', '612.0', '622.0', '174.0']
# labels ['863.0', '599.0', '446.0', '187.0']
# 36 ['72.0', '6.0', '95.0', '87.0']
# 89m ['247.0', '2.0', '197.0', '88.0']
# cls ['792.0', '0.0', '115.0', '81.0']
# 250 ['200.0', '848.0', '228.0', '139.0']
# on ['473.0', '878.0', '165.0', '109.0']
# a ['684.0', '878.0', '71.0', '106.0']
# roll ['806.0', '844.0', '218.0', '141.0']

# %%
def extract_data_from_xml(path):
    tree = ET.parse(path)
    root = tree.getroot()

    image_paths = []
    image_sizes = []
    image_labels = []
    bounding_boxes = []

    for image in root:
        bbs_of_image = []
        labels_of_image = []

        for bbs in image.findall("taggedRectangles"):
            for bb in bbs:
                # check non-alphabet and non-number
                if not bb[0].text.isalnum():
                    continue

                if "é" in bb[0].text.lower() or "ñ" in bb[0].text.lower():
                    continue

                bbs_of_image.append(
                    [
                        float(bb.attrib["x"]),
                        float(bb.attrib["y"]),
                        float(bb.attrib["width"]),
                        float(bb.attrib["height"]),
                    ]
                )
                labels_of_image.append(bb[0].text.lower())

        # Store
        image_paths.append(image[0].text)
        image_sizes.append((int(image[1].attrib["x"]), int(image[1].attrib["y"])))
        bounding_boxes.append(bbs_of_image)
        image_labels.append(labels_of_image)

    return image_paths, image_sizes, image_labels, bounding_boxes

image_paths, image_sizes, image_labels, bounding_boxes = extract_data_from_xml(words_xml_path)

# %%
for path, size, label, bbox in zip(image_paths, image_sizes, image_labels, bounding_boxes):
    print(path, size, label, bbox)
    break
# Out:
# apanar_06.08.2002/IMG_1261.JPG (1600, 1200) ['self', 'adhesive', 'address', 'labels', '36', '89m', 'cls', '250', 'on', 'a', 'roll'] [[174.0, 392.0, 274.0, 195.0], [512.0, 391.0, 679.0, 183.0], [184.0, 612.0, 622.0, 174.0], [863.0, 599.0, 446.0, 187.0], [72.0, 6.0, 95.0, 87.0], [247.0, 2.0, 197.0, 88.0], [792.0, 0.0, 115.0, 81.0], [200.0, 848.0, 228.0, 139.0], [473.0, 878.0, 165.0, 109.0], [684.0, 878.0, 71.0, 106.0], [806.0, 844.0, 218.0, 141.0]]
